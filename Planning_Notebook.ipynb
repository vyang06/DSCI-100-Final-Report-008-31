# %% [markdown]
# **PLANNING ONLY**

# %% [markdown]
# **Title**
#
# Player Age and Average Number of Hours Played are Predictive of Likelihood to Subsribe to a Newsletter (can change later)

# %% [markdown]
# **Introduction**
# - relevant background
# - Clearly state question
# - Identify and describe datasets

# %% [markdown]
# **Methods & results**
# - desribe methods
# - loaded datasets
# - wrangles and cleans data (combine datasets using hashedEmails, clean datasets (remove any unknowns), tunr subscribe into logical variable, tidy)
# - summary desribing relevant data set
# - create a visualization (mean_hours_played vs experience_level Bianca , mean_hours_played vs gender Bianca, subsribe vs gender, subsribe vs experience_level, distribution of player ages)

# %% [markdown]
# **Discussion**
#
# - summarize what you found
# - discuss whether this is what you expected to find
# - discuss what impact could such findings have
# - discuss what future questions could this lead to

# %% [markdown]
# **References**
#
# - if necessary
